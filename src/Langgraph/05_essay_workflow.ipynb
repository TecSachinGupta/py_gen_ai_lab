# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict, Annotated
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import operator

# %%
load_dotenv()

model = ChatOpenAI(model="gpt-5-mini")

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description='Detailed feedback for the essay')
    score: int = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
structured_model.invoke(prompt).feedback
# Out:
# 'Overall impression: The essay is well-structured, clear, and professional in tone. It presents a coherent argument about India’s opportunities and challenges with AI, and it moves logically from strengths to applications, risks, and policy recommendations. Paragraphing is effective and each paragraph focuses on a single theme, which aids readability.\n\nStrengths:\n- Clarity and organization: Ideas are logically ordered and transitions between paragraphs are smooth. The introduction and conclusion frame the piece nicely.\n- Tone and register: The formal, policy-oriented voice fits the topic and audience.\n- Vocabulary and precision: Word choice is mostly appropriate and varied; technical terms (e.g., predictive analytics, data protection) are used correctly.\n- Grammar and mechanics: No major grammatical errors or awkward constructions; sentences are generally well-formed.\n\nAreas for improvement:\n- Specificity and evidence: Several claims (e.g., “over 5 million STEM graduates annually”) would be stronger with citations or concrete examples. Adding a few concrete case studies or data points would increase credibility.\n- Avoiding generalities and clichés: Phrases such as “story in the making” and “age of AI” are broad and somewhat clichéd. Replacing them with more specific language would sharpen the essay’s impact.\n- Sentence variety and concision: A few sentences are wordy or slightly repetitive (for example, similar ideas about inclusion and inequality appear multiple times). Tightening some sentences and varying sentence openings would improve flow.\n- Active voice and specificity in recommendations: Some policy recommendations are general (“adopt a multi-stakeholder approach”); consider adding one or two concrete, actionable steps (e.g., national AI curriculum, public-private data trusts, pilot projects in particular states) to make the conclusion more actionable.\n\nMinor edits: Consider swapping a few passive constructions for active ones (e.g., “India is still shaping its data protection laws” → “India is still developing its data protection framework”), and check for opportunities to replace vague modifiers (“may embrace,” “continues to struggle”) with more precise qualifiers or examples.\n\nOverall score: The essay is competent, persuasive, and readable with only modest revisions needed to strengthen evidence, specificity, and stylistic polish.'

# %%
class EssayState(TypedDict):

    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: EssayState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: EssayState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: EssayState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: EssayState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(EssayState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

# edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

workflow = graph.compile()

# %%
workflow

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
intial_state = {
    'essay': essay
}

workflow.invoke(intial_state)
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'Overall the essay is clear, well-organized and written in a professional, readable register. Strengths: logical structure with coherent paragraphing; good use of topic sentences and transitions; appropriate formal tone and varied vocabulary; virtually error-free grammar and punctuation; clear coverage of opportunities and challenges with relevant sectoral examples (agriculture, healthcare, education). Areas for improvement: occasional generalities and clichés (e.g., “story in the making,” “immense promise”) weaken impact — replacing these with specific evidence or sharper phrasing would strengthen the piece. Some redundancy (repeated references to “AI-driven solutions/systems”) could be reduced by varying wording or consolidating similar points. The essay would benefit from more concrete data or citations to support claims (for example the “over 5 million STEM graduates” figure) and a few tighter sentences to improve concision (e.g., shorten long compound sentences that stack multiple ideas). Stylistically, vary sentence openings and reduce nominalizations to increase readability and energy. Minor suggestions: make the policy recommendations more specific (what kind of regulation, what timelines, examples of successful skilling programs), and tighten the conclusion to avoid platitudes. With small edits for precision and concision this is a strong, publishable short essay.',
#  'analysis_feedback': 'Overall assessment:\nThe essay is a clear, well-structured high-level overview of India’s opportunities and risks in the age of AI. It identifies important domains (agriculture, healthcare, education, governance), highlights core strengths (large STEM talent pool, IT industry, startups), and flags central challenges (digital divide, job displacement, privacy/ethics). The call for a multi‑stakeholder approach and international collaboration is appropriate and constructive.\n\nDepth and limitations:\n- Breadth over depth: The piece covers many relevant topics but remains largely descriptive and general. There is little concrete evidence, data, or case examples to substantiate claims (beyond the single “5 million STEM graduates” figure and the National AI Strategy mention).\n- Policy specifics missing: References to regulation, data protection, and “ethical AI practices” are useful but lack discussion of what concrete policies, governance structures, accountability mechanisms, or timelines would be needed (e.g., regulatory models, oversight bodies, impact assessments).\n- Implementation and operational challenges: The essay does not unpack how initiatives would be operationalized — financing, capacity building, procurement, public‑private partnerships, monitoring and evaluation, or metrics to track AI outcomes. It also omits supply‑side constraints such as compute and data infrastructure, cloud/GPU access, semiconductor dependence, and research funding gaps.\n- Socioeconomic nuance: The treatment of job displacement is cursory. A deeper analysis would discuss which sectors/workforce cohorts are most at risk, feasible reskilling pathways, social safety nets, and transitional labour policies. It also misses discussion of language diversity, accessibility, and cultural context for AI solutions in India’s multilingual population.\n- Risk analysis: Important risks are not explored in depth — e.g., misuse for surveillance, bias in datasets tied to historical exclusion, concentration of AI capability in a few corporations, cybersecurity threats, environmental/energy impacts of large models, and geopolitical/defence implications.\n\nConcrete suggestions to deepen analysis:\n- Add specific examples and evidence: cite existing Indian pilots or platforms (e.g., initiatives by NITI Aayog/IndiaAI, National Digital Health Mission/health data efforts, agricultural extension pilots, BharatNet), and use data on internet penetration, cloud usage, AI funding or startup growth.\n- Provide actionable policy recommendations: propose governance models, data protection elements, procurement rules for public sector AI, certification/audit processes, or legislation comparators (EU AI Act, OECD principles), and outline who (which ministries/agencies) should act.\n- Discuss infrastructure and supply chain: compute/GPU access, domestic semiconductor strategy, data center investment, and edge computing for rural deployment.\n- Flesh out workforce transition: map affected occupations, propose curricula or short-term vocational programs, and suggest metrics for reskilling outcomes.\n- Include metrics and timelines: measurable goals (e.g., X pilots in Y states by 2027, Z% broadband in rural areas), and evaluation frameworks.\n- Conduct a deeper risk/benefit and scenario analysis: short, medium, long-term scenarios, vulnerability analysis (bias, surveillance), and mitigation measures.\n\nScore rationale:\nThe essay is competent as a high‑level primer but lacks the analytic rigor and specificity expected for a deeper policy/strategic paper. With added evidence, concrete policies, implementation details, and a richer risk analysis it could be substantially strengthened.',
#  'clarity_feedback': 'Overall assessment: The essay is generally clear, well-organized, and readable. It presents a concise thesis (India at a critical juncture in the age of AI), follows a logical structure (strengths, applications, challenges, prescriptions, conclusion), and uses sectoral examples (agriculture, healthcare, education, governance) to illustrate its points. Paragraphs have clear topic sentences and transitions that make the argument easy to follow.\n\nStrengths: The essay strikes a balanced tone between opportunity and risk, identifies concrete domains where AI can help, and emphasizes multi-stakeholder approaches and ethics. Its language is accessible and it avoids jargon, making it suitable for a broad audience.\n\nAreas for improvement: Many claims remain high-level and unsupported by data or specific examples. The discussion of government policy ("National AI Strategy (AI for All) in 2020") could be more precise and accompanied by evidence or references. The treatment of key issues—digital divide, job displacement, data protection—is correct but thin; each point would benefit from specific statistics, concrete policy proposals, timelines, or examples of existing programs (e.g., skilling initiatives, pilot projects). The essay repeats some general phrases (AI as an "enabler") rather than adding new analysis. Consider addressing counterarguments (e.g., risk of surveillance, concentration of AI power in large firms) and trade-offs explicitly.\n\nConcrete suggestions: sharpen the thesis to state a clearer call to action; add at least one data point or citation for major claims (graduates per year, internet penetration, etc.); provide one or two specific policy recommendations (e.g., national reskilling targets, data-governance principles like data minimization, algorithmic audits); prioritize the most critical challenges and go deeper on them rather than listing several at equal weight; and end with a more actionable conclusion (next steps, stakeholders, measurable goals).\n\nScore justification: The essay communicates its main ideas clearly and coherently but lacks depth, supporting evidence, and specificity needed for stronger persuasive clarity.',
#  'overall_feedback': 'Summary feedback\n\nOverall assessment\n- A clear, well‑organized, professional short essay that effectively balances opportunities and risks of AI for India. It reads publishable with targeted revisions but currently functions more as a high‑level primer than a detailed policy or analytic paper.\n\nKey strengths\n- Logical structure with coherent paragraphs, strong topic sentences and transitions.\n- Appropriate formal tone, varied vocabulary, and virtually error‑free grammar/punctuation.\n- Good coverage of relevant sectors (agriculture, healthcare, education, governance) and major themes (digital divide, workforce, ethics).\n- Balanced, constructive call for multi‑stakeholder and international collaboration.\n\nMain areas for improvement\n- Breadth over depth: many claims are descriptive and lack supporting data, concrete examples, or citations.\n- Policy and implementation gaps: recommendations are high‑level (regulation, ethics, skilling) but lack specific models, governance mechanisms, timelines, financing, and operational details.\n- Risk analysis is thin: insufficient discussion of surveillance misuse, bias, concentration of power, compute/data infrastructure limits, environmental impact, and geopolitical/defence implications.\n- Language/style refinements: occasional clichés and redundancies, some long/nominalized sentences; could increase energy by varying openings and tightening phrasing.\n- Socioeconomic nuance missing: limited discussion of which jobs/sectors are most at risk, language and accessibility issues in India’s multilingual context, and measurable reskilling pathways.\n\nTop actionable recommendations (priority edits)\n1. Add specific evidence and examples: cite Indian pilots, programs and data (e.g., NITI Aayog/IndiaAI initiatives, NDHM, BharatNet, internet penetration, startup/AI funding figures).\n2. Make policy proposals concrete: propose governance models, oversight bodies, data‑protection elements, procurement rules, certification/audit processes, and suggested timelines (with ministry/agency roles).\n3. Flesh out implementation: discuss financing, capacity building, public‑private partnerships, procurement, monitoring & evaluation, and metrics to track outcomes.\n4. Deepen risk analysis: address surveillance, dataset bias, concentration, cybersecurity, energy impacts, and semiconductor/compute constraints; propose mitigations.\n5. Tighten language and structure: remove clichés, reduce redundancies, shorten long sentences, vary sentence openings, and cut nominalizations.\n6. Prioritize and quantify goals: include measurable targets and short/medium/long‑term scenarios (e.g., pilot counts, broadband targets, reskilling numbers).\n\nFinal note\n- With added evidence, sharper policy specifics, implementation detail, and tighter prose, the essay will move from a strong overview to a substantive, publishable policy piece.',
#  'individual_scores': [6, 8, 7],
#  'avg_score': 7.0}

# %%
intial_state = {
    'essay': essay2
}

workflow.invoke(intial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'Overall assessment:\nThe essay communicates a clear and relevant idea—India’s opportunities and risks with Artificial Intelligence—but its language quality needs substantial improvement. The writer expresses coherent points (agriculture, health, education, jobs, privacy, digital divide) and a basic paragraph structure, but grammar, vocabulary, spelling and sentence formation frequently interfere with clarity.\n\nStrengths:\n- Clear topic and purpose; reader can follow the main argument.\n- Logical organization: positives, problems, and a call for collective action.\n- Uses concrete areas (farmers, doctors, schools, government) to illustrate points.\n\nMain issues and examples (with corrections):\n- Grammar and subject–verb agreement: “India also want become big” -> “India also wants to become a leader.”\n- Articles and determiners missing: “have smart student” -> “has smart students” or “has many smart students.”\n- Spelling and word choice: “engine-ear” -> “engineers”; “peoples” -> “people”; “Artificial Intel… something” -> “Artificial Intelligence (AI).”\n- Informal/casual phrasing and contractions: “no careful” -> “not careful”; “no have phone” -> “do not have phones.”\n- Repetition and redundancy: “big big data” -> “large amounts of data.”\n- Sentence fragments and punctuation: several sentences lack commas or are choppy; combine or expand fragments for flow.\n- Specificity and accuracy: mention of data protection could reference existing efforts (e.g., data protection bills/regulations) rather than “India still make data rule.”\n\nConcrete suggestions to improve the essay:\n1. Begin by defining AI clearly: “Artificial Intelligence (AI) is...”. Use this full term once then the abbreviation.\n2. Fix subject–verb agreement and pluralization throughout (use a grammar checker to catch many errors).\n3. Use articles (a, an, the) appropriately and consistent verb tenses.\n4. Replace informal phrases with standard English and avoid colloquial shortcuts.\n5. Expand and give one specific example per sector (e.g., a named AI application used in Indian agriculture or by an Indian company).\n6. Improve transitions between paragraphs (e.g., “However,” “On the other hand,” “Therefore”).\n7. Proofread for spelling (engineers, people) and punctuation.\n\nExample revision of the opening sentence:\nOriginal: “Now world change very fast because new tech call Artificial Intel… something (AI).”\nRevised: “The world is changing rapidly because of a new technology called Artificial Intelligence (AI).”\n\nFinal verdict:\nThe essay has good ideas but needs focused editing for grammar, vocabulary, and clarity. With careful revision it can become a strong short essay.\n',
#  'analysis_feedback': 'Score: 3/10\n\nWhat the essay does well:\n- Identifies important, high-level issues: opportunity from AI, sectors that could benefit (agriculture, health, education, government), and key risks (digital divide, job displacement, privacy).\n- Emphasizes inclusion — that AI should benefit everyone, not only the rich — which is the right theme for a policy discussion.\n\nMain weaknesses (depth of analysis):\n- Very superficial treatment: claims are general and repetitive but unsupported. There are no facts, figures, examples, case studies, or citations to back up assertions.\n- No clear thesis or structured argument. The essay lists opportunities and risks but does not analyze trade-offs, propose concrete solutions, or prioritize actions.\n- Missing policy detail: it mentions data/privacy issues and government programs but does not name specific policies, institutions, or feasible interventions (e.g., data-protection frameworks, digital-infrastructure programs, skilling initiatives).\n- Limited nuance: important technical and ethical questions (bias, explainability, accountability, regulatory capacity) are not discussed. Economic impacts (which jobs are likely affected, timelines, or mitigation strategies) are absent.\n- Language and clarity problems: many grammatical and stylistic errors reduce credibility and make arguments harder to follow.\n\nHow to improve the depth of analysis (actionable suggestions):\n1. Start with a clear thesis: e.g., “AI can accelerate India’s development if supported by inclusive infrastructure, robust governance, and targeted skilling; otherwise it may widen inequality.” Use that to structure the essay.\n2. Use a structured outline: introduction (thesis), separate sections on opportunities, challenges, and concrete policy recommendations, then a short conclusion.\n3. Add evidence and examples: cite one or two specific programs or pilots (e.g., national AI strategy, digital health initiatives, extensions of BharatNet/PM-WANI) or recent studies/estimates to show scale and credibility. If unsure about names, use reputable sources such as government strategy documents, World Bank or industry reports.\n4. Deepen analysis of challenges: explain which jobs or regions are most at risk, how bias in datasets can harm marginalized groups, and why privacy/data governance is hard in India’s context.\n5. Offer concrete, prioritized recommendations: expand digital infrastructure (rural broadband), strengthen data protection and privacy laws, invest in reskilling and vocational programs, design safety nets for displaced workers, promote public–private pilots in farming and health, and require transparency/explainability in deployed systems.\n6. Discuss implementation and trade-offs: cost, timelines, institutional roles (centre vs. states), and measurement (KPIs for an “AI for All” program). Propose simple metrics to evaluate success (e.g., increases in farm yield attributable to AI, number of citizens with access to digital services, reduction in time for government service delivery).\n7. Improve language and coherence: proofread for grammar, use varied vocabulary, and avoid repetition. Each paragraph should make one clear point supported by evidence or example.\n\nIf you revise the essay, focus on one sector (say agriculture) for a deeper case study, or keep the multi-sector approach but give at least one concrete example and one specific policy recommendation per sector. That will move the piece from a surface-level overview to a substantive analytical essay.',
#  'clarity_feedback': 'Overall clarity: The essay communicates a clear, basic argument: AI is a fast-growing technology that offers opportunities for India but also poses risks, and India must pursue an inclusive, well-regulated approach. That central idea is understandable to a reader. The essay’s strengths are its straightforward thesis, identification of both benefits (agriculture, health, education, government efficiency) and risks (digital divide, job loss, privacy), and its call for collective action.\n\nMain weaknesses affecting clarity:\n- Language and grammar: Frequent spelling, grammatical and word-choice errors (e.g., “Artificial Intel… something,” “engine-ear,” “no have phone”) make some sentences hard to follow and reduce the essay’s credibility. \n- Sentence-level clarity: Many short, choppy sentences and informal phrasing create a disjointed flow. Some thoughts are repeated without development. \n- Structure and organization: Paragraphs are brief and unevenly developed. The essay would be clearer with distinct introduction, body paragraphs each focused on one point (benefit or risk), and a stronger conclusion. Transitions between ideas are weak. \n- Lack of specificity and evidence: Claims are general—naming a few concrete examples, data, or policies (for example, NITI Aayog’s AI strategy, Digital India initiatives, or specific company projects) would make the argument more persuasive and clearer. \n- Balance and nuance: Important trade-offs (e.g., how to retrain workers, how to ensure rural access) are mentioned but not explained. The essay would benefit from proposing concrete steps or policy ideas.\n\nActionable suggestions to improve clarity:\n1. Correct grammar and spelling: Proofread or use a grammar tool to fix basic errors and improve word choice.\n2. Reorganize: Start with a clear introduction that defines AI and states the thesis. Use separate paragraphs for benefits, risks, and solutions. End with a concise, decisive conclusion.\n3. Use topic sentences and transitions: Begin each paragraph with one clear sentence that states the point, then support it with examples or explanation.\n4. Add specifics: Cite one or two concrete examples, statistics, or policies to ground claims (e.g., particular AI applications in Indian agriculture or health, government programs). \n5. Expand solutions: Replace vague calls to “teach AI” with specific recommendations (digital infrastructure investment, data protection law, reskilling programs, public–private partnerships).\n6. Vary sentence structure: Combine related short sentences into more complex sentences to improve flow and reduce repetition.\n\nScore justification: The essay’s central message is intelligible and its identification of benefits and risks is appropriate, but persistent language errors, weak organization, lack of specifics, and superficial treatment of solutions substantially reduce clarity and effectiveness. For these reasons I assign a score of 5 out of 10.',
#  'overall_feedback': 'Summary feedback\n\nOverall assessment\nThe essay presents a clear, relevant idea — India’s opportunities and risks from Artificial Intelligence — and a logical structure (benefits, problems, call to action). However, frequent language errors and a superficial treatment of issues weaken clarity and analytic depth. With focused editing and stronger evidence-based argumentation it can become a solid short policy essay.\n\nKey strengths\n- Clear topic and purpose; reader can follow the main argument.\n- Logical organization (positives, negatives, call for collective action).\n- Uses concrete sectors (agriculture, health, education, government) to illustrate points.\n\nMain weaknesses\n- Language problems: grammar, subject–verb agreement, articles, spelling, word choice, sentence fragments and punctuation frequently interfere with clarity and credibility.\n- Shallow analysis: assertions are general and repetitive with no facts, examples, case studies, or citations.\n- Lack of specificity: policy and institutional detail (which programs, regulations, timelines) are missing.\n- Weak structure and flow: short choppy paragraphs, poor transitions, and no clear thesis or prioritized recommendations.\n\nTop actionable suggestions (prioritized)\n1. Open with a clear thesis and definition: e.g., “The world is changing rapidly because of a new technology called Artificial Intelligence (AI).” State one-line thesis that guides the essay.\n2. Reorganize: introduction (thesis), distinct paragraphs for opportunities, challenges, and concrete policy recommendations, then a concise conclusion.\n3. Add evidence and concrete examples: name one or two programs, pilots, companies, or statistics (e.g., NITI Aayog’s AI strategy, BharatNet, a specific digital-health pilot) to support claims.\n4. Deepen analysis and recommendations: explain which jobs/regions are most at risk, how bias and privacy issues will affect marginalized groups, and offer prioritized, feasible policies (digital infrastructure, data protection law, reskilling programs, public–private pilots, KPIs).\n5. Improve language and mechanics: fix subject–verb agreement, articles, spelling, punctuation; avoid informal phrasing; use a grammar checker and proofread.\n6. Improve flow: use topic sentences, transitions (“However,” “Therefore”), and combine short choppy sentences to reduce repetition.\n7. Make solutions implementable: assign likely actors (centre vs. states, private sector), suggest timelines, costs/trade-offs, and simple metrics to measure success.\n\nExample revised opening sentence\n“The world is changing rapidly because of a new technology called Artificial Intelligence (AI).”\n\nFinal verdict\nGood ideas and structure but needs two parallel efforts: careful language editing and deeper, evidence-based analysis with concrete policy proposals. With those changes the essay can move from a superficial overview to a persuasive, substantive piece.\n\nScores (from detailed feedback)\n- Depth of analysis: 3/10\n- Clarity of thought: 5/10',
#  'individual_scores': [3, 4, 5],
#  'avg_score': 4.0}

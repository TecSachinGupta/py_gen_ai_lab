# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
# define state
class BMIState(TypedDict):

    weight_kg: float
    height_m: float
    bmi: float
    category: str

# %%
def calculate_bmi(state: BMIState) -> BMIState:

    weight = state['weight_kg']
    height = state['height_m']

    bmi = weight/(height**2)

    state['bmi'] = round(bmi, 2)

    return state

# %%
def label_bmi(state: BMIState) -> BMIState:

    bmi = state['bmi']

    if bmi < 18.5:
        state["category"] = "Underweight"
    elif 18.5 <= bmi < 25:
        state["category"] = "Normal"
    elif 25 <= bmi < 30:
        state["category"] = "Overweight"
    else:
        state["category"] = "Obese"

    return state

# %%
# define your graph
graph = StateGraph(BMIState)

# add nodes to your graph
graph.add_node('calculate_bmi', calculate_bmi)
graph.add_node('label_bmi', label_bmi)

# add edges to your graph
graph.add_edge(START, 'calculate_bmi')
graph.add_edge('calculate_bmi', 'label_bmi')
graph.add_edge('label_bmi', END)


# compile the graph
workflow = graph.compile()

# %%
# execute the graph
intial_state = {'weight_kg':80, 'height_m':1.73}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'weight_kg': 80, 'height_m': 1.73, 'bmi': 26.73, 'category': 'Overweight'}

# %%
workflow.get_graph().print_ascii()
# Out:
#   +-----------+
#   | __start__ |
#   +-----------+
#         *
#         *
#         *
# +---------------+
# | calculate_bmi |
# +---------------+
#         *
#         *
#         *
#   +-----------+
#   | label_bmi |
#   +-----------+
#         *
#         *
#         *
#    +---------+
#    | __end__ |
#    +---------+

# %%
workflow
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langgraph\pregel\main.py:758, in Pregel._repr_mimebundle_(self, **kwargs)
#     754 def _repr_mimebundle_(self, **kwargs: Any) -> dict[str, Any]:
#     755     """Mime bundle used by Jupyter to display the graph"""
#     756     return {
#     757         "text/plain": repr(self),
# --> 758         "image/png": self.get_graph().draw_mermaid_png(),
#     759     }
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph.py:702, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config)
#     692 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     693     draw_mermaid_png,
#     694 )
#     696 mermaid_syntax = self.draw_mermaid(
#     697     curve_style=curve_style,
#     698     node_colors=node_colors,
#     699     wrap_label_n_words=wrap_label_n_words,
#     700     frontmatter_config=frontmatter_config,
#     701 )
# --> 702 return draw_mermaid_png(
#     703     mermaid_syntax=mermaid_syntax,
#     704     output_file_path=output_file_path,
#     705     draw_method=draw_method,
#     706     background_color=background_color,
#     707     padding=padding,
#     708     max_retries=max_retries,
#     709     retry_delay=retry_delay,
#     710 )
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316     )
#     317 else:
#     318     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:463, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay)
#     458     # For other status codes, fail immediately
#     459     msg = (
#     460         "Failed to reach https://mermaid.ink/ API while trying to render "
#     461         f"your graph. Status code: {response.status_code}.\n\n"
#     462     ) + error_msg_suffix
# --> 463     raise ValueError(msg)
#     465 except (requests.RequestException, requests.Timeout) as e:
#     466     if attempt < max_retries:
#     467         # Exponential backoff with jitter
#
# ValueError: Failed to reach https://mermaid.ink/ API while trying to render your graph. Status code: 502.
#
# To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 from IPython.display import Image
# ----> 2 Image(workflow.get_graph().draw_mermaid_png())
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph.py:702, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config)
#     692 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     693     draw_mermaid_png,
#     694 )
#     696 mermaid_syntax = self.draw_mermaid(
#     697     curve_style=curve_style,
#     698     node_colors=node_colors,
#     699     wrap_label_n_words=wrap_label_n_words,
#     700     frontmatter_config=frontmatter_config,
#     701 )
# --> 702 return draw_mermaid_png(
#     703     mermaid_syntax=mermaid_syntax,
#     704     output_file_path=output_file_path,
#     705     draw_method=draw_method,
#     706     background_color=background_color,
#     707     padding=padding,
#     708     max_retries=max_retries,
#     709     retry_delay=retry_delay,
#     710 )
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316     )
#     317 else:
#     318     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File c:\Users\sachingupta07\Downloads\MyWorkspace\py_gen_ai_lab\.venvlg\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:463, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay)
#     458     # For other status codes, fail immediately
#     459     msg = (
#     460         "Failed to reach https://mermaid.ink/ API while trying to render "
#     461         f"your graph. Status code: {response.status_code}.\n\n"
#     462     ) + error_msg_suffix
# --> 463     raise ValueError(msg)
#     465 except (requests.RequestException, requests.Timeout) as e:
#     466     if attempt < max_retries:
#     467         # Exponential backoff with jitter
#
# ValueError: Failed to reach https://mermaid.ink/ API while trying to render your graph. Status code: 502.
#
# To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`
